# %%
import sqlite3
import json

raw_election_data_db = "election_data.db"
constituency_data_db = "constituency_data.db"
conn = sqlite3.connect(raw_election_data_db)

# %%
def execute_query(query):
    cursor = conn.cursor()

    cursor.execute(query)
    results = cursor.fetchall()
    column_names = [description[0] for description in cursor.description]
    data = []
    for row in results:
        row_dict = {column_names[i]: row[i] for i in range(len(column_names))}
        data.append(row_dict)
    return data

# %%
sql_ = """
SELECT Party,
count(Party) as Contested,
sum(CASE WHEN Position = 1 THEN 1 ELSE 0 END) as Won, 
avg(CASE WHEN Position = 1 THEN Margin_Percentage ELSE 0 END) as AverageWinMargin,
sum(CASE WHEN Position = 2 THEN 1 ELSE 0 END) as RunnerUp,
sum(CASE WHEN Position > 2 THEN 1 ELSE 0 END) as AlsoRan 
from all_election_data where year=2019 and State_Name="Bihar" 
group by Party
order by Won desc
limit 10
""" 
print(json.dumps(execute_query(sql_), indent=4))
# Out:
# [
#     {
#         "Party": "BJP",
#         "Contested": 17,
#         "Won": 17,
#         "AverageWinMargin": 23.64294117647059,
#         "RunnerUp": 0,
#         "AlsoRan": 0
#     },
#     {
#         "Party": "JD(U)",
#         "Contested": 17,
#         "Won": 16,
#         "AverageWinMargin": 18.864117647058823,
#         "RunnerUp": 1,
#         "AlsoRan": 0
#     },
#     {
#         "Party": "LJP",
#         "Contested": 7,
#         "Won": 7,
#         "AverageWinMargin": 20.955714285714286,
#         "RunnerUp": 0,
#         "AlsoRan": 0
#     },
#     {
#         "Party": "INC",
#         "Contested": 10,
#         "Won": 1,
#         "AverageWinMargin": 0.313,
#         "RunnerUp": 9,
#         "AlsoRan": 0
#     },
#     {
#         "Party": "ravp",
#         "Contested": 1,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 1
#     },
#     {
#         "Party": "mimm",
#         "Contested": 1,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 1
#     },
#     {
#         "Party": "Yuva Krantikari Party",
#         "Contested": 1,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 1
#     },
#     {
#         "Party": "YKP",
#         "Contested": 4,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 4
#     },
#     {
#         "Party": "Wazib Adhikar Party",
#         "Contested": 1,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 1
#     },
#     {
#         "Party": "WAP",
#         "Contested": 1,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 1
#     }
# ]

# %%
sql_ = """PRAGMA table_info(all_election_data)"""
print(json.dumps(execute_query(sql_), indent=4))
# Out:
# [
#     {
#         "cid": 0,
#         "name": "State_Name",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 1,
#         "name": "Assembly_No",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 2,
#         "name": "Constituency_No",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 3,
#         "name": "Year",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 4,
#         "name": "month",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 5,
#         "name": "Poll_No",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 6,
#         "name": "DelimID",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 7,
#         "name": "Position",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 8,
#         "name": "Candidate",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 9,
#         "name": "Sex",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 10,
#         "name": "Party",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 11,
#         "name": "Votes",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 12,
#         "name": "Candidate_Type",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 13,
#         "name": "Valid_Votes",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 14,
#         "name": "Electors",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 15,
#         "name": "Constituency_Name",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 16,
#         "name": "Constituency_Type",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 17,
#         "name": "Sub_Region",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 18,
#         "name": "N_Cand",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 19,
#         "name": "Turnout_Percentage",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 20,
#         "name": "Vote_Share_Percentage",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 21,
#         "name": "Deposit_Lost",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 22,
#         "name": "Margin",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 23,
#         "name": "Margin_Percentage",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 24,
#         "name": "ENOP",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 25,
#         "name": "pid",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 26,
#         "name": "Party_Type_TCPD",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 27,
#         "name": "Party_ID",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 28,
#         "name": "last_poll",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 29,
#         "name": "Contested",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 30,
#         "name": "Last_Party",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 31,
#         "name": "Last_Party_ID",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 32,
#         "name": "Last_Constituency_Name",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 33,
#         "name": "Same_Constituency",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 34,
#         "name": "Same_Party",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 35,
#         "name": "No_Terms",
#         "type": "REAL",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 36,
#         "name": "Turncoat",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 37,
#         "name": "Incumbent",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 38,
#         "name": "Recontest",
#         "type": "INTEGER",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 39,
#         "name": "MyNeta_education",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 40,
#         "name": "TCPD_Prof_Main",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 41,
#         "name": "TCPD_Prof_Main_Desc",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 42,
#         "name": "TCPD_Prof_Second",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 43,
#         "name": "TCPD_Prof_Second_Desc",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     },
#     {
#         "cid": 44,
#         "name": "Election_Type",
#         "type": "TEXT",
#         "notnull": 0,
#         "dflt_value": null,
#         "pk": 0
#     }
# ]

# %%
sql_ = """SELECT 
Party, 
count(Party) as Contested, 
sum(CASE WHEN Position = 1 THEN 1 ELSE 0 END) as Won, 
avg(CASE WHEN Position = 1 THEN Margin_Percentage ELSE 0 END) as AverageWinMargin, 
sum(CASE WHEN Position = 2 THEN 1 ELSE 0 END) as RunnerUp, 
sum(CASE WHEN Position > 2 THEN 1 ELSE 0 END) as AlsoRan 
from all_election_data where year=2019 and State_Name='West_Bengal'
group by Party order by Won desc limit 10"""
print(json.dumps(execute_query(sql_), indent=4))
# Out:
# [
#     {
#         "Party": "AITC",
#         "Contested": 42,
#         "Won": 22,
#         "AverageWinMargin": 6.264285714285715,
#         "RunnerUp": 19,
#         "AlsoRan": 1
#     },
#     {
#         "Party": "BJP",
#         "Contested": 42,
#         "Won": 18,
#         "AverageWinMargin": 3.9640476190476193,
#         "RunnerUp": 22,
#         "AlsoRan": 2
#     },
#     {
#         "Party": "INC",
#         "Contested": 40,
#         "Won": 2,
#         "AverageWinMargin": 0.17124999999999999,
#         "RunnerUp": 1,
#         "AlsoRan": 37
#     },
#     {
#         "Party": "grac",
#         "Contested": 1,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 1
#     },
#     {
#         "Party": "WPOI",
#         "Contested": 2,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 2
#     },
#     {
#         "Party": "SWJP",
#         "Contested": 1,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 1
#     },
#     {
#         "Party": "SUCI(C)",
#         "Contested": 42,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 42
#     },
#     {
#         "Party": "STPI",
#         "Contested": 1,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 1
#     },
#     {
#         "Party": "SHS",
#         "Contested": 16,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 16
#     },
#     {
#         "Party": "SDPI",
#         "Contested": 1,
#         "Won": 0,
#         "AverageWinMargin": 0.0,
#         "RunnerUp": 0,
#         "AlsoRan": 1
#     }
# ]

# %%
sql_ = """
SELECT distinct(State_Name) from all_election_data where year = 2019
"""
print(json.dumps(execute_query(sql_), indent=4))
# Out:
# [
#     {
#         "State_Name": "Andaman_&_Nicobar_Islands"
#     },
#     {
#         "State_Name": "Andhra_Pradesh"
#     },
#     {
#         "State_Name": "Arunachal_Pradesh"
#     },
#     {
#         "State_Name": "Assam"
#     },
#     {
#         "State_Name": "Bihar"
#     },
#     {
#         "State_Name": "Chandigarh"
#     },
#     {
#         "State_Name": "Chhattisgarh"
#     },
#     {
#         "State_Name": "Dadra_&_Nagar_Haveli"
#     },
#     {
#         "State_Name": "Daman_&_Diu"
#     },
#     {
#         "State_Name": "Delhi"
#     },
#     {
#         "State_Name": "Goa"
#     },
#     {
#         "State_Name": "Gujarat"
#     },
#     {
#         "State_Name": "Haryana"
#     },
#     {
#         "State_Name": "Himachal_Pradesh"
#     },
#     {
#         "State_Name": "Jammu_&_Kashmir"
#     },
#     {
#         "State_Name": "Jharkhand"
#     },
#     {
#         "State_Name": "Karnataka"
#     },
#     {
#         "State_Name": "Kerala"
#     },
#     {
#         "State_Name": "Lakshadweep"
#     },
#     {
#         "State_Name": "Madhya_Pradesh"
#     },
#     {
#         "State_Name": "Maharashtra"
#     },
#     {
#         "State_Name": "Manipur"
#     },
#     {
#         "State_Name": "Meghalaya"
#     },
#     {
#         "State_Name": "Mizoram"
#     },
#     {
#         "State_Name": "Nagaland"
#     },
#     {
#         "State_Name": "Odisha"
#     },
#     {
#         "State_Name": "Puducherry"
#     },
#     {
#         "State_Name": "Punjab"
#     },
#     {
#         "State_Name": "Rajasthan"
#     },
#     {
#         "State_Name": "Sikkim"
#     },
#     {
#         "State_Name": "Tamil_Nadu"
#     },
#     {
#         "State_Name": "Telangana"
#     },
#     {
#         "State_Name": "Tripura"
#     },
#     {
#         "State_Name": "Uttar_Pradesh"
#     },
#     {
#         "State_Name": "Uttarakhand"
#     },
#     {
#         "State_Name": "West_Bengal"
#     }
# ]

# %%
sql_ = """
SELECT Constituency_Name, max(Winner), max(RunnerUp) from
(
    Select Constituency_Name, CASE WHEN Position=1 THEN Party END as Winner, CASE WHEN Position=2 THEN Party END as RunnerUp from
    all_election_data
    where year=2019
    and State_Name = 'Maharashtra'
    and (Winner is not null or RunnerUp is not null)
)
group by Constituency_Name
"""
print(json.dumps(execute_query(sql_), indent=4))
# Out:
# [
#     {
#         "Constituency_Name": "AHMADNAGAR",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "AKOLA",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "VBA"
#     },
#     {
#         "Constituency_Name": "AMRAVATI",
#         "max(Winner)": "IND",
#         "max(RunnerUp)": "SHS"
#     },
#     {
#         "Constituency_Name": "AURANGABAD",
#         "max(Winner)": "AIMIM",
#         "max(RunnerUp)": "SHS"
#     },
#     {
#         "Constituency_Name": "BARAMATI",
#         "max(Winner)": "NCP",
#         "max(RunnerUp)": "BJP"
#     },
#     {
#         "Constituency_Name": "BEED",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "BHANDARA - GONDIYA",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "BHIWANDI",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "BULDHANA",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "CHANDRAPUR",
#         "max(Winner)": "INC",
#         "max(RunnerUp)": "BJP"
#     },
#     {
#         "Constituency_Name": "DHULE",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "DINDORI",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "GADCHIROLI-CHIMUR",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "HATKANANGLE",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "SWP"
#     },
#     {
#         "Constituency_Name": "HINGOLI",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "JALGAON",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "JALNA",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "KALYAN",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "KOLHAPUR",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "LATUR",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "MADHA",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "MAVAL",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "MUMBAI   SOUTH",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "MUMBAI NORTH",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "MUMBAI NORTH CENTRAL",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "MUMBAI NORTH EAST",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "MUMBAI NORTH WEST",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "MUMBAI SOUTH CENTRAL",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "NAGPUR",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "NANDED",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "NANDURBAR",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "NASHIK",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "OSMANABAD",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "PALGHAR",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "BVA"
#     },
#     {
#         "Constituency_Name": "PARBHANI",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "PUNE",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "RAIGAD",
#         "max(Winner)": "NCP",
#         "max(RunnerUp)": "SHS"
#     },
#     {
#         "Constituency_Name": "RAMTEK",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "RATNAGIRI - SINDHUDURG",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "MSHP"
#     },
#     {
#         "Constituency_Name": "RAVER",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "SANGLI",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "SWP"
#     },
#     {
#         "Constituency_Name": "SATARA",
#         "max(Winner)": "NCP",
#         "max(RunnerUp)": "SHS"
#     },
#     {
#         "Constituency_Name": "SHIRDI",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "SHIRUR",
#         "max(Winner)": "NCP",
#         "max(RunnerUp)": "SHS"
#     },
#     {
#         "Constituency_Name": "SOLAPUR",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "THANE",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "NCP"
#     },
#     {
#         "Constituency_Name": "WARDHA",
#         "max(Winner)": "BJP",
#         "max(RunnerUp)": "INC"
#     },
#     {
#         "Constituency_Name": "YAVATMAL-WASHIM",
#         "max(Winner)": "SHS",
#         "max(RunnerUp)": "INC"
#     }
# ]
